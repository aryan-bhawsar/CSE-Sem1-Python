# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan-bhawsar/CSE-Sem1-Python/blob/main/python%20practicals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter an integer: "))
decimal = float(input("Enter a float value: "))
text = input("Enter a string: ")

print("Integer:", num)
print("Float:", decimal)
print("String:", text)
